# %%
import math
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import shap
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler

from scipy.cluster import hierarchy
from scipy.spatial.distance import squareform
from scipy.stats import spearmanr

# %%
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)

# %%
raw_data = pd.read_csv("data/Main_Data_SOM.csv")

# %%
columns = raw_data.columns.to_list()

# %%
# Ideally we want to have the genus of the microbes 
# But for now, drop columns where they couldn't identify genus or family
# (And keep ones where the family was identified but not the genus)
unidentified_microbes = [i for i in columns if i[-5:] == "__;__"]
print(f"Found {len(unidentified_microbes)} unidentified microbes:")
# print(unidentified_microbes)
# Out:
# Found 33 unidentified microbes:

# %%
# Rows that begin with "Zero (Phase"
# TODO: ask Mona what they are
# print(raw_data['Index'])
raw_data = raw_data.drop(labels=[0,41])

# %%
# Create a new column that separates out the day number in the experiment
def days(x):
    # this finds the integers and returns a list of integers found
    # we return the first one found
    # so for example in "2R6" we return 2
    return re.findall(r'\d+', x)[0]

raw_data['day'] = raw_data['Index'].map(days)

# Create a new column that separates out the experiment pH
def ph(x):
    if x[-1] in ["R", "M", "N"]:
        return 7.5
    else:
        # if we don't delete rows that say "Zero (Phase X)" etc then
        # this doesn't work
        return 6.0

raw_data["pH"] = raw_data['Index'].map(ph)

# Create a new column that separates out the temperature
def temperature(x):
    if x[-1] in ["R", "6"]:
        return "Control"
    elif x[-1] in ["M", "J"]:
        return "100C"
    elif x[-1] in ["N", "K"]:
        return "140C"
    else:
        # we shouldn't get here
        return "Uncategorized"

raw_data["temperature"] = raw_data['Index'].map(temperature)

# %%
# # Now we have these columns separated out in case we want to group on them
# # For analysis
# raw_data[['Index', 'day', 'pH', 'temperature']].head(10)

# %%
# make a list of the microbes

raw_columns = raw_data.columns.to_list()
microbe_columns = [i for i in raw_columns if ";" in i]
print(len(microbe_columns))
# Out:
# 527

# %%
# Mona's method of filtering by relative abundance

filtered_data = pd.read_csv("data/filtered_df5.csv")
filtered_columns = filtered_data.columns.to_list()
filtered_microbe_columns = [i for i in filtered_columns if ";" in i]
print(len(filtered_microbe_columns))
# Out:
# 40

# %%
# Normalize data for RF comparison
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(raw_data[microbe_columns])

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Random Forest
# [[https://www.geeksforgeeks.org/machine-learning/feature-selection-using-random-forest/]]

# %% [markdown]
# ### Random Forest Classifier - First Pass / Comparisons

# %%
# first create our classes
raw_data["Hexanoic Acid"].quantile([0,.33,.66,1])
# Out:
# 0.00      0.000000
# 0.33     12.641790
# 0.66     97.338819
# 1.00    763.079707
# Name: Hexanoic Acid, dtype: float64

# %%
def classify(x):
    """adapted from Mona's code.
    Classify acid into three group by quantile"""
    x = x.to_numpy(dtype=float) # transform to list
    quantile = np.quantile(x, [0.33, 0.66]) # separate into three quantiles
    groups = np.select([
                    x <= quantile[0],
                    (x > quantile[0]) & (x <= quantile[1]),
                    x > quantile[1]
            ],
                   ['Low', 'Medium', 'High'], default="Other")
    return groups

raw_data["butyric_class"] = classify(raw_data["Butyric Acid"])
raw_data["hexanoic_class"] = classify(raw_data["Hexanoic Acid"])

# %%
n_estimators = 1000
random_seed = 11
X = raw_data[microbe_columns]
y = raw_data["butyric_class"]
rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_seed)
rf.fit(X, y)

importances = rf.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

def pretty_taxa_labels(x):
    """x is a list/array of full taxonomy names
    We're scrubbing it down to just the genus name
    for readability on charts"""
    pretty = []
    for i in x:
        genus_section = i.split(';')[-1] # pull just the genus from the taxonomy
        genus = genus_section.removeprefix('g__')  # remove the "g__" prefix
        if genus == "__":
            genus = "unclassified"
        pretty.append(genus)
    return pretty
    
def rf_plot(feature_importance_df, random_seed, method='Classifier', target=None, feature_overlap=None, overlap_label=None, measure=None):
    """Feature importance df: comes out of random forest
    Random seed: the numpy random seed you want to use
    method: classifier or regressor (this is just to title the plot)
    target: the target the feature importance has been trained on (this is just to title the plot)
    feature_overlap: a list of features to compare as a color,     overlap_label: a label for the feature comparison as a color"""
    
    fig, ax = plt.subplots(figsize=(10, 6))
    red = "tab:red"
    blue = "tab:blue"
    red_count = 0
    blue_count = 0
    features_to_show = feature_importance_df.shape[0]

    bar_colors = []
    if not feature_overlap:
        feature_overlap = filtered_microbe_columns
    for feature in feature_importance_df['Feature']:
        if feature in feature_overlap:
            bar_colors.append(blue)
            blue_count += 1
        else:
            bar_colors.append(red)
            red_count += 1

    if not measure:
        measure = "Gini Impurity"
            
    ax.bar(feature_importance_df['Feature'],feature_importance_df['Importance'], color=bar_colors)
    ax.set_ylabel(f"Feature Importance ({measure})", fontsize=10)
    ax.set_title(f"Random Forest {method} - {target} Top {feature_importance_df.shape[0]} Features, Random Seed {random_seed}")
    # Rotate x-axis tick labels
    cats = pretty_taxa_labels(feature_importance_df['Feature'])
    ax.set_xticklabels(cats, rotation=90, ha='right', fontsize=8) # 'ha' for horizontal alignment
    ax.set_xlabel("Genus")
    plt.axhline(.005, color='black', linewidth=1)  # add a horizontal line at impurity = 0.005

    if not overlap_label:
        overlap_label = "Relative Abundance feature list"

    
    red_patch = mpatches.Patch(color=red, label=f"Missing from {overlap_label}\n ({red_count}/{features_to_show})")
    blue_patch = mpatches.Patch(color=blue, label=f"In both feature sets ({blue_count}/{features_to_show})")
    ax.legend(handles=[red_patch, blue_patch])

    plt.tight_layout() # Adjust layout to prevent labels from overlapping
    plt.show()

rf_plot(feature_importance_df.head(40), random_seed, method='Classifier',target="Butyric Acid")

# # use this later for comparison against other seeds
# feature_importance_11 = feature_importance_df

# # use for later comparison against regression
feature_importance_cls = feature_importance_df
# Out:
# /var/folders/wp/lq_w646n77jc1slxh2r_13f00000gn/T/ipykernel_88012/1460514296.py:58: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(cats, rotation=90, ha='right', fontsize=8) # 'ha' for horizontal alignment

# %%
# test impact that normalization has
# result: looks exactly the same as the 500 tree version

n_estimators = 1000
random_seed = 11
X = raw_data[filtered_microbe_columns]
y = raw_data["butyric_class"]
rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_seed)
rf.fit(X, y)

importances = rf.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': filtered_microbe_columns, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

rf_plot(feature_importance_df.head(40), random_seed, method='Classifier',target="Butyric Acid", 
        feature_overlap=feature_importance_cls['Feature'][:40].to_list(),
       overlap_label="Top 40 Feature List for RF trained with all features")

# # test impact that normalization has
# # result: looks exactly the same as the 500 tree version

# n_estimators = 500
# random_seed = 11
# X = normalized_data
# y = raw_data["butyric_class"]
# rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_seed)
# rf.fit(X, y)

# importances = rf.feature_importances_
# feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# rf_plot(feature_importance_df.head(60), random_seed, method='Classifier',target="Butyric Acid")
# Out:
# /var/folders/wp/lq_w646n77jc1slxh2r_13f00000gn/T/ipykernel_88012/1460514296.py:58: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(cats, rotation=90, ha='right', fontsize=8) # 'ha' for horizontal alignment

# %%
# # test impact that dropping unimportant features has (vs RF with the full feature set)

# # without further tuning, 2 features in the top 60 don't match (and they are almost at the 
# # bottom of the top feature list)
# # so dropping unimportant features doesn't seem to have a big impact on feature ordering

# # run RF
# n_estimators = 500
# random_seed = 11
# X = raw_data[microbe_columns]
# y = raw_data["butyric_class"]
# rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_seed)
# rf.fit(X, y)
# importances = rf.feature_importances_
# feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances}).sort_values(by='Importance', ascending=False)
# feature_comparison_df = feature_importance_df['Feature'][:60].to_list()

# # get features with feature importance > 0.001
# relevant_feature_df = feature_importance_df[feature_importance_df['Importance'] > 0.001]
# relevant_features = relevant_feature_df['Feature'].to_list()
# print(len(relevant_features))  # 221 of them

# # rerun RF with just those features
# X = raw_data[relevant_features]
# y = raw_data["butyric_class"]
# rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_seed)
# rf.fit(X, y)
# importances = rf.feature_importances_
# feature_importance_df = pd.DataFrame({'Feature': relevant_features, 'Importance': importances})
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# # plot to compare against full feature set
# rf_plot(feature_importance_df.head(60), random_seed, method='Classifier',target="Butyric Acid", feature_overlap=feature_comparison,
#        overlap_label="Top 60 Feature List for RF trained with all features")

# %%
# # compare to a different random seed

# other_seed_list = feature_importance_11['Feature'][:60].to_list()

# n_estimators = 500
# random_seed = 118
# X = raw_data[microbe_columns]
# y = raw_data["butyric_class"]
# rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_seed)
# rf.fit(X, y)

# importances = rf.feature_importances_
# feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# rf_plot(feature_importance_df.head(60), random_seed, method='Classifier',target="Butyric Acid", feature_overlap=other_seed_list,
#        overlap_label="Top 60 Features from random seed 11")

# %%
# # compare to a different random seed 

# n_estimators = 500
# random_seed = 1700
# X = raw_data[microbe_columns]
# y = raw_data["butyric_class"]
# rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_seed)
# rf.fit(X, y)

# importances = rf.feature_importances_
# feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
# top_features = feature_importance_df['Feature'][:10].values

# rf_plot(feature_importance_df.head(60), random_seed, method='Classifier',target="Butyric Acid", feature_overlap=other_seed_list,
#        overlap_label="Top 60 Features from random seed 11")

# %% [markdown]
# ### Random Forest Regressor - First Pass / Comparisons

# %%
n_estimators = 1000
random_seed = 11
X = raw_data[microbe_columns]
y = raw_data["Butyric Acid"]
rf = RandomForestRegressor(n_estimators=n_estimators, random_state=random_seed)
rf.fit(X, y)

importances = rf.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
top_features = feature_importance_df['Feature'][:10].values

rf_plot(feature_importance_df.head(40), random_seed, method='Regressor', target="Butyric Acid")
feature_importance_11 = feature_importance_df
# Out:
# /var/folders/wp/lq_w646n77jc1slxh2r_13f00000gn/T/ipykernel_88012/1460514296.py:58: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(cats, rotation=90, ha='right', fontsize=8) # 'ha' for horizontal alignment

# %%
# compare to classifier

other_seed_list = feature_importance_cls['Feature'][:60].to_list()

n_estimators = 1000
random_seed = 11
X = raw_data[filtered_microbe_columns]
y = raw_data["Butyric Acid"]
rf = RandomForestRegressor(n_estimators=n_estimators, random_state=random_seed)
rf.fit(X, y)

importances = rf.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': filtered_microbe_columns, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
top_features = feature_importance_df['Feature'][:10].values

rf_plot(feature_importance_df.head(60), random_seed, method='Regressor', target="Butyric Acid", 
        feature_overlap=feature_importance_11['Feature'][:40].to_list(),
       overlap_label="RF Regressor Top 40 Features")

# # test impact of normalization
# # no visible difference

# n_estimators = 500
# random_seed = 11
# X = normalized_data
# y = raw_data["Butyric Acid"]
# rf = RandomForestRegressor(n_estimators=n_estimators, random_state=random_seed)
# rf.fit(X, y)

# importances = rf.feature_importances_
# feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
# top_features = feature_importance_df['Feature'][:10].values

# rf_plot(feature_importance_df.head(60), random_seed, method='Regressor', target="Butyric Acid")
# Out:
# /var/folders/wp/lq_w646n77jc1slxh2r_13f00000gn/T/ipykernel_88012/1460514296.py:58: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(cats, rotation=90, ha='right', fontsize=8) # 'ha' for horizontal alignment

# %%
# compare to classifier

other_seed_list = feature_importance_cls['Feature'][:60].to_list()

n_estimators = 500
random_seed = 11
X = raw_data[microbe_columns]
y = raw_data["Butyric Acid"]
rf = RandomForestRegressor(n_estimators=n_estimators, random_state=random_seed)
rf.fit(X, y)

importances = rf.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
top_features = feature_importance_df['Feature'][:10].values

rf_plot(feature_importance_df.head(60), random_seed, method='Regressor', target="Butyric Acid", feature_overlap=other_seed_list,
       overlap_label="RF Classifier top 60 feature list (same seed)")
# Out:
# /var/folders/wp/lq_w646n77jc1slxh2r_13f00000gn/T/ipykernel_88012/1460514296.py:58: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(cats, rotation=90, ha='right', fontsize=8) # 'ha' for horizontal alignment

# %%
# # compare to a different random seed

# other_seed_list = feature_importance_11['Feature'][:60].to_list()

# n_estimators = 500
# random_seed = 118
# X = raw_data[microbe_columns]
# y = raw_data["Butyric Acid"]
# rf = RandomForestRegressor(n_estimators=n_estimators, random_state=random_seed)
# rf.fit(X, y)

# importances = rf.feature_importances_
# feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
# top_features = feature_importance_df['Feature'][:10].values

# rf_plot(feature_importance_df.head(60), random_seed, method='Regressor', target="Butyric Acid", feature_overlap=other_seed_list,
#        overlap_label="Top 60 Features from random seed 11")

# %%
# # compare to a different random seed

# n_estimators = 500
# random_seed = 1700
# X = raw_data[microbe_columns]
# y = raw_data["Butyric Acid"]
# rf = RandomForestRegressor(n_estimators=n_estimators, random_state=random_seed)
# rf.fit(X, y)

# importances = rf.feature_importances_
# feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})
# feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# use_these_top_features = feature_importance_df['Feature'][:4].values

# rf_plot(feature_importance_df.head(60), random_seed, method='Regressor',target="Butyric Acid", feature_overlap=other_seed_list,
#        overlap_label="Top 60 Features from random seed 11")

# %% [markdown]
# ### RF Classifier / Permutation Importance: Tuning and Multicollinearity Removal

# %%
# switch to using Permutation Importance
# We can see the feature importance dropping due to multicollinearity
# so first, reduce features by dropping the least important ones
# this approximately halves the number of features
# Result: still bad permutation importance

n_estimators = 500
random_seed = 11
X = raw_data[microbe_columns]
y = raw_data["butyric_class"]

rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_seed)
rf.fit(X, y)
importances = rf.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': microbe_columns, 'Importance': importances})

relevant_feature_df = feature_importance_df[feature_importance_df['Importance'] > 0.001]
relevant_features = relevant_feature_df['Feature'].to_list()
print(len(relevant_features)) # 221 out of 500ish

# doing an RF with Permutation Importance right now still results in a permutation importance of 0 for everything

# rerun RF with just those features
fil_X = raw_data[relevant_features]
fil_y = raw_data["butyric_class"]

fil_rf = RandomForestClassifier(n_estimators=n_estimators, random_state=random_seed)
fil_rf.fit(fil_X, fil_y)
fil_importances = fil_rf.feature_importances_
fil_feature_importance_df = pd.DataFrame({'Feature': relevant_features, 'Importance': fil_importances})
fil_feature_importance_df = fil_feature_importance_df.sort_values(by='Importance', ascending=False)
print(fil_feature_importance_df.head())

permutation_result = permutation_importance(
    fil_rf, fil_X, fil_y, n_repeats=10, random_state=42, n_jobs=2
)

permutation_importance_df = pd.DataFrame({'Feature': relevant_features,
    'Importance': permutation_result.importances_mean}
)
permutation_importance_df = permutation_importance_df.sort_values(by="Importance", ascending=False)
permutation_importance_df.head()

rf_plot(permutation_importance_df.head(60), random_seed, method='Classifier',target="Butyric Acid", measure="Permutation Importance")
# Out:
# 221
#                                                Feature  Importance
# 150  d__Bacteria;p__Firmicutes;c__Clostridia;o__Osc...    0.031979
# 136  d__Bacteria;p__Firmicutes;c__Clostridia;o__Osc...    0.023089
# 22   d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...    0.020714
# 188  d__Bacteria;p__Patescibacteria;c__Saccharimona...    0.018411
# 197  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...    0.016461
# /var/folders/wp/lq_w646n77jc1slxh2r_13f00000gn/T/ipykernel_88012/1460514296.py:58: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(cats, rotation=90, ha='right', fontsize=8) # 'ha' for horizontal alignment

# %%
# # Started testing a way to drop microbe columns by clustering
# # This feels like it's starting with what we're trying to achieve, though
# # https://scikit-learn.org/stable/auto_examples/inspection/plot_permutation_importance_multicollinear.html

# corr = spearmanr(fil_X).correlation

# # Ensure the correlation matrix is symmetric
# corr = np.nan_to_num(corr)
# corr = (corr + corr.T) / 2
# np.fill_diagonal(corr, 1)
# np.array_equal(corr, corr.T)

# # fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
# fig, ax1 = plt.subplots()

# # We convert the correlation matrix to a distance matrix before performing
# # hierarchical clustering using Ward's linkage.
# distance_matrix = 1 - np.abs(corr)
# dist_linkage = hierarchy.ward(squareform(distance_matrix))
# dendro = hierarchy.dendrogram(
#     dist_linkage, labels=pretty_taxa_labels(fil_X.columns.to_list()), ax=ax1, leaf_rotation=90
# )
# dendro_idx = np.arange(0, len(dendro["ivl"]))

# # ax2.imshow(corr[dendro["leaves"], :][:, dendro["leaves"]])
# # ax2.set_xticks(dendro_idx)
# # ax2.set_yticks(dendro_idx)
# # ax2.set_xticklabels(pretty_taxa_labels(dendro["ivl"]), rotation="vertical")
# # ax2.set_yticklabels(pretty_taxa_labels(dendro["ivl"]))
# # plt.show()

# %%
# optimize performance using GridSearchCV
# this is very different than optimizing for stable features

# rf = RandomForestClassifier()
# parameters = {
#     'n_estimators': [50,100,500,1000],
#     'min_samples_split': [2,5,10],
#     'max_depth': [3,10,50,None]
# }
# clf = GridSearchCV(rf, parameters)
# clf.fit(raw_data[microbe_columns], raw_data['butyric_class'])


# # Get the best parameters and best score
# print("Best parameters:", clf.best_params_)
# print("Best cross-validation score:", clf.best_score_)

# # Use the best model
# best_rf = clf.best_estimator_

# # tune random forest 

# seed_set = [11, 118, 1700, 11]

# n_estimators = [
#     50,
#     100, 
#     500,
#     1000
# ]
# min_samples_split = [
#     2,
#     5,
#     10]
# max_depth = [
#     3,
#     10,
#     50,
#     None]

# X = raw_data[microbe_columns]
# y = raw_data["butyric_class"]

# for n in n_estimators:
#     for m in min_samples_split:
#         for d in max_depth:
#             print(f"\n# N_ESTIMATORS = {n}")
#             print(f"### MIN_SAMPLES = {m}")
#             print(f"##### MAX_DEPTH = {d}")
#             comp = []
            
#             for s in seed_set:
#                 print(f"###### SEED = {s}")
#                 rf = RandomForestClassifier(n_estimators=n, min_samples_split=m, max_depth=d, random_state=s)
#                 rf.fit(X, y)
#                 importances = rf.feature_importances_
#                 feature_importance_df = pd.DataFrame({'Feature': pretty_taxa_labels(microbe_columns), 'Importance': importances}).sort_values(by='Importance', ascending=False)
#                 comp.append(feature_importance_df['Feature'][:10].to_list())

#             count = np.zeros((len(seed_set), len(seed_set)))
            
#             for i, s in enumerate(comp):
#                 for j, r in enumerate(comp):
#                     sub_count = 0
#                     for f,c in enumerate(s):
#                         for k,e in enumerate(r):
#                             if c == e:
#                                 sub_count += 1
#                     count[i,j] = sub_count

#             print(count)
#             break

# %% [markdown]
# # SHAP values

# %%
# Train RF classifier
n = 1000
m = 2
d = None
s = 11
X = raw_data[microbe_columns]
y = raw_data["butyric_class"]
rf = RandomForestClassifier(n_estimators=n, min_samples_split=m, max_depth=d, random_state=s)
rf.fit(X, y)

# compute shap values
explainer = shap.TreeExplainer(rf, X)
shap_values = explainer(X)
shap_values.feature_names = pretty_taxa_labels(microbe_columns)

# use group_remaining_features to remove the 
shap.plots.beeswarm(shap_values[:, :, 2], max_display=20, group_remaining_features=False, show=False)
plt.title('SHAP Values for High Butyric Acid classification (all taxonomies)')
# Out:
# Text(0.5, 1.0, 'SHAP Values for High Butyric Acid classification (all taxonomies)')

# %%
# Train RF regressor
n = 1000
m = 2
d = None
s = 11
X = raw_data[microbe_columns]
y = raw_data["Butyric Acid"]
rf = RandomForestRegressor(n_estimators=n, min_samples_split=m, max_depth=d, random_state=s)
rf.fit(X, y)

# compute shap values
explainer = shap.TreeExplainer(rf, X)
shap_values = explainer(X)
shap_values.feature_names = pretty_taxa_labels(microbe_columns)

# use group_remaining_features to remove the 
shap.plots.beeswarm(shap_values, max_display=20, group_remaining_features=False, show=False)
plt.title('SHAP Values for Butyric Acid Regression')
# Out:
# Text(0.5, 1.0, 'SHAP Values for Butyric Acid Regression')

# %%
# Train RF classifier on just filtered columns 
n = 1000
m = 2
d = None
s = 11
X = raw_data[filtered_microbe_columns]
y = raw_data["butyric_class"]
rf = RandomForestClassifier(n_estimators=n, min_samples_split=m, max_depth=d, random_state=s)
rf.fit(X, y)

# compute shap values
explainer = shap.TreeExplainer(rf, X)
shap_values = explainer(X)
shap_values.feature_names = pretty_taxa_labels(filtered_microbe_columns)

# use group_remaining_features to remove the 
shap.plots.beeswarm(shap_values[:, :, 2], max_display=20, group_remaining_features=False, show=False)
plt.title('SHAP Values for High Butyric Acid classification (Filtered Dataset)')
# Out:
# Text(0.5, 1.0, 'SHAP Values for High Butyric Acid classification (Filtered Dataset)')

# %% [markdown]
# # Self Organizing Map

# %%
class HexSOM():

    def __init__(self, height, width, depth, feature_avgs, seed=37):
        self.height = height
        self.width = width
        self.depth = depth  # this is the number of features in each sample
        self.feature_avgs = feature_avgs # per feature avg over the training data
        self.random_seed = seed
        self.Weights = self._make_weights()

    def _make_weights(self):
        """Make a centroid based weight matrix"""
        # create a matrix of vectors of the column averages
        Means = np.broadcast_to(self.feature_avgs, (self.height,self.width,self.depth))

        # create a random matrix of -1s to 1s
        # Then scale that by 1/10 so we have -.1s to .1s
        np.random.seed(self.random_seed)  # set a seed so we can replicate exactly
        Random_init = (np.random.random((self.height, self.width, self.depth)) * 2 - 1) * 0.1

        # Multiply that random scaling by the means, then add that to the means
        return Means.copy() + Random_init * Means

    def bmu_index(self,v):
        """
        Returns the index of the weight vector with the minimum euclidean distance
        to the sample vector v at hand.
        argmin: Returns the indices of the minimum values along an axis.
        unravel_index: Converts a flat index or array of flat indices into a tuple of coordinate arrays.
        """
        euclidean_distances = np.linalg.norm(self.Weights-v, axis=2)
        return np.unravel_index(np.argmin(euclidean_distances), euclidean_distances.shape)

    def _get_immediate_neighbors(self,start_index):
        (i,j) = start_index

        # get neighbors as offset columns
        if j%2==1:
            neighbors = [
                (i, j-1),
                (i+1, j-1),
                (i-1, j),
                (i+1,j),
                (i, j+1),
                (i+1, j+1)
            ]
        else:
            neighbors = [
                (i-1,j-1),
                (i,j-1),
                (i-1,j),
                (i+1,j),
                (i-1,j-1),
                (i,j+1)
            ]
        
        # check for negative indices which could happen at the edges
        neighbors_checked = [(p,q) for (p,q) in neighbors if p>=0 and q>=0 and p<self.height and q<self.width]
        return neighbors_checked

    def _get_neighbors(self,start_index, neighborhood_size):
        """Get the neighbors by iterating outward"""
        full_neighborhood = [start_index]
        for m in range(neighborhood_size):
            for n in full_neighborhood.copy():  # so we don't add to list while iter
                new_neighbors = self._get_immediate_neighbors(n)
                full_neighborhood.extend(new_neighbors)
            full_neighborhood = list(set(full_neighborhood)) # dedupe

        full_neighborhood.remove(start_index)  # not actually sure if we do need to remove this
        return self._get_immediate_neighbors(start_index)
        
    def _update_weights(self,v, bmu_index, alpha, neighborhood_size):
        neighboring_indices = self._get_neighbors(bmu_index, neighborhood_size)
        for coord in neighboring_indices:
            self.Weights[coord] += alpha * (v - self.Weights[coord])

    def train(self, training_data, alpha_init=0.9, max_iter=100, neighborhood_init=None):
        """Todo: implement varying neighborhood size for hex neighborhood"""
        
        for t in range(max_iter):
            # shuffle training data
            training_data = training_data.sample(frac=1)
            print(f"######### T={t} ########")

            # update hyperparams
            alpha = alpha_init * (1 - t/max_iter)
            print(f"Alpha = {alpha}")
            if not neighborhood_init:
                neighborhood_init = self.height // 5
            neighborhood_size = math.ceil(neighborhood_init * (1 - t/max_iter))
            print(f"Neighborhood size = {neighborhood_size}")

            # iterate through training_data sample by sample
            for sample_vector in training_data.to_numpy():

                # for each sample, find the index of the weight unit
                # that is closest to the sample vector
                bmu_index = self.bmu_index(sample_vector)

                # update the weight neighborhood
                self._update_weights(sample_vector, bmu_index, alpha=alpha, neighborhood_size=neighborhood_size)

    def predict(self, test_data):
        """Return coordinates of BMU for each test sample"""
        predictions = []
        for v in test_data.to_numpy():
            predictions.append(self.bmu_index(v))
        return predictions

# %%
# training_features = raw_data[use_these_top_features]
# column_avgs = training_features.mean()

# hexanoic_SOM = HexSOM(20,20,training_features.shape[1], column_avgs)
# hexanoic_SOM.train(training_features,max_iter=3)
# training_predictions = hexanoic_SOM.predict(training_features)

# %%
# training_labels = 'pH ' + raw_data['pH'].astype('str') + ', ' + raw_data['temperature'].astype('str')+ ', :Day ' + raw_data['day'].astype('str')

# fig,ax = plt.subplots()

# x = []
# y = []
# for (i,j) in training_predictions:
#     x.append(i)
#     y.append(j)
# ax.scatter(x,y,labels=training_labels)
